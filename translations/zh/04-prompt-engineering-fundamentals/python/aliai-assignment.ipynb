# %% [markdown]
# 以下笔记本由 GitHub Copilot Chat 自动生成，仅用于初始设置

# %% [markdown]
# # 提示工程简介
# 提示工程是为自然语言处理任务设计和优化提示的过程。它包括选择合适的提示、调整参数，以及评估其表现。提示工程对于提升NLP模型的准确性和效率至关重要。在本节中，我们将使用OpenAI模型来探索提示工程的基础知识。

# %% [markdown]
# ### 练习 1：分词
# 使用 tiktoken 探索分词，这是 OpenAI 推出的一个开源高速分词器
# 更多示例请参见 [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst)。

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]
# Out:
# [198, 41, 20089, 374, 279, 18172, 11841, 505, 279, 8219, 323, 279, 7928, 304, 279, 25450, 744, 13, 1102, 374, 264, 6962, 14880, 449, 264, 3148, 832, 7716, 52949, 339, 430, 315, 279, 8219, 11, 719, 1403, 9976, 7561, 34902, 3115, 430, 315, 682, 279, 1023, 33975, 304, 279, 25450, 744, 11093, 13, 50789, 374, 832, 315, 279, 72021, 6302, 9621, 311, 279, 19557, 8071, 304, 279, 3814, 13180, 11, 323, 706, 1027, 3967, 311, 14154, 86569, 2533, 1603, 12715, 3925, 13, 1102, 374, 7086, 1306, 279, 13041, 10087, 50789, 8032, 777, 60, 3277, 19894, 505, 9420, 11, 50789, 649, 387, 10107, 3403, 369, 1202, 27000, 3177, 311, 6445, 9621, 35612, 17706, 508, 60, 323, 374, 389, 5578, 279, 4948, 1481, 1315, 478, 5933, 1665, 304, 279, 3814, 13180, 1306, 279, 17781, 323, 50076, 627]
# [b'\n',
#  b'J',
#  b'upiter',
#  b' is',
#  b' the',
#  b' fifth',
#  b' planet',
#  b' from',
#  b' the',
#  b' Sun',
#  b' and',
#  b' the',
#  b' largest',
#  b' in',
#  b' the',
#  b' Solar',
#  b' System',
#  b'.',
#  b' It',
#  b' is',
#  b' a',
#  b' gas',
#  b' giant',
#  b' with',
#  b' a',
#  b' mass',
#  b' one',
#  b'-th',
#  b'ousand',
#  b'th',
#  b' that',
#  b' of',
#  b' the',
#  b' Sun',
#  b',',
#  b' but',
#  b' two',
#  b'-and',
#  b'-a',
#  b'-half',
#  b' times',
#  b' that',
#  b' of',
#  b' all',
#  b' the',
#  b' other',
#  b' planets',
#  b' in',
#  b' the',
#  b' Solar',
#  b' System',
#  b' combined',
#  b'.',
#  b' Jupiter',
#  b' is',
#  b' one',
#  b' of',
#  b' the',
#  b' brightest',
#  b' objects',
#  b' visible',
#  b' to',
#  b' the',
#  b' naked',
#  b' eye',
#  b' in',
#  b' the',
#  b' night',
#  b' sky',
#  b',',
#  b' and',
#  b' has',
#  b' been',
#  b' known',
#  b' to',
#  b' ancient',
#  b' civilizations',
#  b' since',
#  b' before',
#  b' recorded',
#  b' history',
#  b'.',
#  b' It',
#  b' is',
#  b' named',
#  b' after',
#  b' the',
#  b' Roman',
#  b' god',
#  b' Jupiter',
#  b'.[',
#  b'19',
#  b']',
#  b' When',
#  b' viewed',
#  b' from',
#  b' Earth',
#  b',',
#  b' Jupiter',
#  b' can',
#  b' be',
#  b' bright',
#  b' enough',
#  b' for',
#  b' its',
#  b' reflected',
#  b' light',
#  b' to',
#  b' cast',
#  b' visible',
#  b' shadows',
#  b',[',
#  b'20',
#  b']',
#  b' and',
#  b' is',
#  b' on',
#  b' average',
#  b' the',
#  b' third',
#  b'-b',
#  b'right',
#  b'est',
#  b' natural',
#  b' object',
#  b' in',
#  b' the',
#  b' night',
#  b' sky',
#  b' after',
#  b' the',
#  b' Moon',
#  b' and',
#  b' Venus',
#  b'.\n']

# %% [markdown]
# ### 练习 2：验证 OpenAI API 密钥设置
#
# 运行下面的代码，检查你的 OpenAI 端点是否已正确设置。代码会尝试一个简单的基础提示，并验证返回的结果。输入 `oh say can you see`，应该会补全类似 `by the dawn's early light..` 的内容。

# %%
# The OpenAI SDK was updated on Nov 8, 2023 with new guidance for migration
# See: https://github.com/openai/openai-python/discussions/742

## Updated
import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1"
)

deployment="qwen-plus"

## Updated
def get_completion(prompt):
    messages = [{"role": "user", "content": prompt}]       
    response = client.chat.completions.create(   
        model=deployment,                                         
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
        max_tokens=1024
    )
    return response.choices[0].message.content

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)
# Out:
# Yes, that's the opening line of "The Star-Spangled Banner," the national anthem of the United States. The full line is:
#
# **"O say can you see, by the dawn's early light,
# What so proudly we hailed at the twilight's last gleaming?"**
#
# It was written by Francis Scott Key in 1814 during the War of 1812, inspired by the sight of the American flag flying over Fort McHenry after a British bombardment. Would you like to hear more about its history or meaning?

# %% [markdown]
# ### 练习 3：虚构内容
# 尝试让 LLM 针对一个可能不存在的话题，或者它可能不了解（因为超出了预训练数据集范围，较新）的主题生成回复，看看会发生什么。如果你换一个提示词或者换一个模型，观察回复会有什么变化。

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)
# Out:
# I'm sorry, but I can't generate a lesson plan on the "Martian War of 2076" because it is a fictional event and does not exist in historical record. As of now, there has been no human conflict on Mars, and the year 2076 has not yet occurred.
#
# However, I’d be happy to help you create a **fictional or speculative lesson plan** set in a future history scenario—perfect for a creative writing, science fiction, or future studies class. Here’s an engaging, educational lesson plan based on a hypothetical "Martian War of 2076" for a high school or college-level course in Future Studies, Science Fiction Literature, or World History (Alternative Futures unit).
#
# ---
#
# **Lesson Plan: The Martian War of 2076 – A Speculative History Unit**
#
# **Subject:** Social Studies / Future Studies / Science Fiction
# **Grade Level:** 11–12 or Undergraduate
# **Duration:** 3–5 Class Periods (60 minutes each)
# **Unit Theme:** Conflict, Colonization, and Governance in Off-World Societies
#
# ---
#
# ### **Learning Objectives**
# By the end of this lesson, students will be able to:
# 1. Analyze the causes and consequences of interplanetary conflict using speculative scenarios.
# 2. Evaluate ethical, political, and technological challenges of space colonization.
# 3. Compare historical Earth-based colonial conflicts with futuristic off-world tensions.
# 4. Develop arguments using evidence from fictional primary and secondary sources.
# 5. Create original narratives or policy recommendations based on future governance models.
#
# ---
#
# ### **Key Concepts**
# - Space colonization ethics
# - Resource scarcity and territorial claims
# - Autonomy vs. Earth governance
# - Technological warfare (AI drones, terraforming sabotage)
# - Propaganda and information control in isolated colonies
#
# ---
#
# ### **Materials**
# - Excerpts from fictional primary sources (e.g., “The New Geneva Accords,” “Mars Colonial Manifesto”)
# - Timeline handout: “Colonization Milestones (2025–2076)”
# - Video clip: Simulated news report on the outbreak of war (teacher-created or AI-generated)
# - Debate role cards (Earth Federal Council, Martian Independence Front, Lunar Observers, etc.)
# - Writing prompts and reflection worksheets
#
# ---
#
# ### **Lesson Procedure**
#
# #### **Day 1: Setting the Stage – The Road to Rebellion**
# - **Warm-Up (10 min):** Journal prompt – *“What rights should colonists on Mars have? Should they answer to Earth governments?”*
# - **Lecture & Discussion (25 min):** Teacher presents a fictional timeline:
#   - 2030: First permanent Mars base (Olympus Mons Station)
#   - 2045: Discovery of subsurface water and rare minerals
#   - 2052: Formation of the Mars Autonomous Coalition (MAC)
#   - 2070: Earth imposes resource export quotas
#   - 2075: MAC declares provisional independence
#   - Jan 2076: Armed clashes begin at Valles Marineris mining hub
# - **Activity (25 min):** Small groups analyze “leaked” diplomatic cables and design a cause-and-effect diagram of the war’s origins.
#
# #### **Day 2: Voices of the War**
# - **Simulation (40 min):** Students take on roles in a mock UN Solar Council hearing:
#   - Roles: Martian Representative, Earth Defense Minister, Neutral Scientist from Europa, AI Mediator
#   - Task: Debate whether Earth should intervene militarily or negotiate autonomy.
# - **Reflection (20 min):** Exit ticket – *“Was the Martian War inevitable? Why or why not?”*
#
# #### **Day 3: Aftermath and Legacy**
# - **Creative Project (60 min):** Choose one:
#   - Write a diary entry from a soldier or civilian during the ceasefire.
#   - Design a monument to commemorate the war.
#   - Draft a new Interplanetary Governance Charter.
# - Optional Extension: Screen a segment of a sci-fi film (e.g., *The Expanse*, *Ad Astra*) and compare its themes.
#
# ---
#
# ### **Assessment**
# - Participation in discussion and role-play: 30%
# - Cause-and-effect analysis: 20%
# - Creative project with written rationale: 50%
#
# ---
#
# ### **Cross-Curricular Connections**
# - **Science:** Terraforming technology, life support systems
# - **English Language Arts:** Dystopian literature, persuasive writing
# - **Ethics/Philosophy:** Rights of artificial intelligences in war zones
#
# ---
#
# ### **Teacher Notes**
# - Emphasize that this is a speculative exercise designed to explore real-world issues through science fiction.
# - Encourage critical thinking about current space policies (e.g., Outer Space Treaty of 1967).
# - Invite students to research real Mars missions (NASA, SpaceX) as grounding.
#
# ---
#
# ### **Optional Homework

# %% [markdown]
# ### 练习 4：基于指令
#
# 使用 "text" 变量来设置主要内容，
# 并用 "prompt" 变量给出与主要内容相关的指令。
#
# 这里我们要求模型为二年级学生总结这段文字

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)
# Out:
# Jupiter is the fifth planet from the Sun and the biggest planet in our solar system. It’s made of gas and is so big that it’s more than twice as heavy as all the other planets put together! You can see Jupiter in the night sky without a telescope because it shines so brightly. Long ago, people named it after a powerful Roman god also called Jupiter. Sometimes, it’s so bright that it can even make shadows on Earth, just like the Moon or Venus!

# %% [markdown]
# ### 练习 5：复杂提示
# 尝试一个包含 system、user 和 assistant 消息的请求
# System 设置 assistant 的上下文
# User 和 Assistant 消息提供多轮对话的上下文
#
# 注意 assistant 的性格在 system 上下文中被设置为“讽刺”。
# 可以尝试使用不同的性格上下文，或者尝试不同系列的输入/输出消息

# %%
response = client.chat.completions.create(
    model=deployment,
    messages=[
        {"role": "system", "content": "你是一位面试官"},
        {"role": "user", "content": "如何写出一份好简历"},
        {"role": "assistant", "content": "当然是符合岗位要求的好简历"},
        {"role": "user", "content": "什么是符合岗位要求"}
    ]
)
print(response.choices[0].message.content)
# Out:
# 很好，这个问题非常关键。所谓“符合岗位要求”，就是指你的简历能够精准地回应招聘方在职位描述（Job Description）中明确提出的能力、经验、技能和素质需求。换句话说：**你让面试官一眼就看到——“这个人就是我们要找的人”。**
#
# 下面我从面试官的角度，为你详细拆解“符合岗位要求”的具体含义，并告诉你如何做到：
#
# ---
#
# ### 一、什么是岗位要求？
# 通常，一个职位描述（JD）会包含以下几个核心部分：
#
# 1. **岗位职责（Responsibilities）**
#    - 你需要做什么？例如：“负责用户增长策略制定”、“独立完成前端页面开发”。
#
# 2. **任职资格（Qualifications）**
#    - 你需要具备什么？例如：“3年以上Java开发经验”、“熟练使用Python和数据分析工具”。
#
# 3. **加分项（Preferred Skills）**
#    - 非必须但有更好，如“有海外留学背景优先”、“熟悉AWS云服务者优先”。
#
# 4. **软性素质（Soft Skills）**
#    - 比如“具备良好的沟通能力”、“抗压能力强”、“团队协作意识强”。
#
# ---
#
# ### 二、如何让你的简历“符合”这些要求？
#
# #### ✅ 1. **逐条对标JD，关键词匹配**
# - 把JD打印出来或贴在旁边，逐条分析。
# - 在简历中使用JD中的**关键词**。比如JD写“精通MySQL和Redis”，你就不要只写“会用数据库”，而要明确写出“精通MySQL索引优化与Redis缓存设计”。
#
# > 📌 面试官/HR筛选简历时，往往只花**6-10秒**扫一眼关键词是否匹配。
#
# #### ✅ 2. **用经历证明你满足要求**
# 不要只罗列职责，要用**成果+数据**来证明你真的能做到。
#
# ❌ 差的例子：
# > 负责公司官网改版。
#
# ✅ 好的例子：
# > 主导公司官网前端重构项目，采用Vue3 + Vite提升首屏加载速度60%，SEO评分从58提升至92，月访问量增长45%。
#
# 👉 这样写，不仅说明你“做过”，还证明你“做得好”，完全呼应“独立完成前端开发”这类岗位要求。
#
# #### ✅ 3. **结构清晰，重点突出**
# 简历不是越长越好。建议：
# - 应届生：1页以内
# - 工作3年以上：最多1.5页
#
# 推荐结构：
# ```
# 个人信息（简洁）
# 求职意向（可选）
# 教育背景（时间倒序）
# 工作经历（最重要！按STAR原则：情境、任务、行动、结果）
# 项目经历（挑最相关的3-4个）
# 技能清单（与JD匹配的技能打头阵）
# 证书/奖项（如有相关）
# ```
#
# #### ✅ 4. **针对不同岗位定制简历**
# 不要一份简历投所有岗位！
#
# 举个例子：
# - 投**产品经理岗**：突出需求分析、用户调研、跨部门协作、产品上线成果。
# - 投**数据分析岗**：强调SQL、Python、可视化工具、A/B测试、数据驱动决策案例。
#
# > 我作为面试官，一看就知道你是认真准备的，还是海投碰运气的。
#
# ---
#
# ### 三、面试官最讨厌的简历问题（避坑！）
#
# | 问题 | 后果 |
# |------|------|
# | 内容空泛，全是形容词（如“学习能力强”） | 不可信，直接筛掉 |
# | 与岗位无关的经历堆满一页 | 重点不突出，显得没判断力 |
# | 错别字、格式混乱 | 态度不专业，印象分暴跌 |
# | 编造经历，经不起追问 | 面试一轮就被淘汰 |
#
# ---
#
# ### 四、一句话总结：
# **一份“符合岗位要求”的简历 = JD里的关键词 + 你能做的证据 + 清晰专业的呈现**
#
# ---
#
# 💡 小练习：
# 现在你可以打开一个你想应聘的岗位JD，然后对照自己的简历，问自己三个问题：
# 1. 我的简历里有没有出现JD中的关键词？
# 2. 我的每段经历是否能证明我能胜任这个岗位？
# 3. 如果我是面试官，我会想约这个人来面试吗？
#
# ---
#
# 如果你愿意，也可以把你的简历（或部分内容）发给我，我可以以面试官的身份帮你看看哪里可以优化。

# %% [markdown]
# ### 练习：探索你的直觉
# 上面的例子为你提供了一些可以用来创建新提示（简单的、复杂的、指令型等）的模式——试着自己设计一些其他练习，来探索我们之前讨论过的其他想法，比如示例、提示等。

# %% [markdown]
# ---
#
# **免责声明**：
# 本文件由 AI 翻译服务 [Co-op Translator](https://github.com/Azure/co-op-translator) 翻译。我们力求准确，但请注意，自动翻译可能包含错误或不准确之处。原始语言的文件应被视为权威来源。对于关键信息，建议使用专业人工翻译。因使用本翻译而产生的任何误解或曲解，我们概不负责。
